# %% [markdown]
# <a href="https://colab.research.google.com/github/JeetVyas25/Food-Emission/blob/main/Food_Production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing required libraries
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the dataset
df_food = pd.read_csv("/content/Food_Production.csv")

# %%
#Checking the shape of dataset
df_food.shape
# Out:
# (43, 23)

# %%
#Checking the first rows of the dataset
df_food.head()
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
# 2        Barley (Beer)              0.0          0.0   0.2         0.1
# 3              Oatmeal              0.0          0.0   1.4         0.0
# 4                 Rice              0.0          0.0   3.6         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
# 2        0.0       0.5     0.3              1.1
# 3        0.1       0.1     0.0              1.6
# 4        0.1       0.1     0.1              4.0
#
#    Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
# ...

# %%
#To display all the columns we use below code
pd.set_option("display.max_columns", None)

# %%
#checking last five rows of the dataset
df_food.tail()
# Out:
#         Food product  Land use change  Animal Feed  Farm  Processing  \
# 38              Milk              0.5          0.2   1.5         0.1
# 39            Cheese              4.5          2.3  13.1         0.7
# 40              Eggs              0.7          2.2   1.3         0.0
# 41     Fish (farmed)              0.5          0.8   3.6         0.0
# 42  Shrimps (farmed)              0.2          2.5   8.4         0.0
#
#     Transport  Packging  Retail  Total_emissions  \
# 38        0.1       0.1     0.3              2.8
# 39        0.1       0.2     0.3             21.2
# 40        0.1       0.2     0.0              4.5
# 41        0.1       0.1     0.0              5.1
# 42        0.2       0.3     0.2             11.8
#
#     Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  \
# 38                                          17.750000
# 39                                          25.418605
# 40                                          15.111111
# ...

# %%
#Checking statistical analysis of the  dataset
df_food.describe()
# Out:
#        Land use change  Animal Feed       Farm  Processing  Transport  \
# count        43.000000    43.000000  43.000000   43.000000  43.000000
# mean          1.260465     0.453488   3.469767    0.253488   0.195349
# std           3.357730     0.919200   7.083264    0.372475   0.158795
# min          -2.100000     0.000000   0.100000    0.000000   0.000000
# 25%           0.000000     0.000000   0.350000    0.000000   0.100000
# 50%           0.200000     0.000000   0.800000    0.100000   0.100000
# 75%           0.800000     0.000000   2.200000    0.300000   0.200000
# max          16.300000     2.900000  39.400000    1.300000   0.800000
#
#         Packging     Retail  Total_emissions  \
# count  43.000000  43.000000        43.000000
# mean    0.269767   0.069767         5.972093
# std     0.342633   0.110270        10.501753
# min     0.000000   0.000000         0.200000
# 25%     0.100000   0.000000         0.850000
# 50%     0.100000   0.000000         1.600000
# ...

# %%
df_food.dtypes
# Out:
# Food product                                                                object
# Land use change                                                            float64
# Animal Feed                                                                float64
# Farm                                                                       float64
# Processing                                                                 float64
# Transport                                                                  float64
# Packging                                                                   float64
# Retail                                                                     float64
# Total_emissions                                                            float64
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   float64
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                   float64
# ...

# %%
#Checking null values
df_food.isnull().sum()
# Out:
# Food product                                                                0
# Land use change                                                             0
# Animal Feed                                                                 0
# Farm                                                                        0
# Processing                                                                  0
# Transport                                                                   0
# Packging                                                                    0
# Retail                                                                      0
# Total_emissions                                                             0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   10
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                    5
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      16
# ...

# %%
print(df_food.columns)
# Out:
# Index(['Food product', 'Land use change', 'Animal Feed', 'Farm', 'Processing',
#        'Transport', 'Packging', 'Retail', 'Total_emissions',
#        'Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)',
#        'Eutrophying emissions per kilogram (gPO₄eq per kilogram)',
#        'Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)',
#        'Freshwater withdrawals per 1000kcal (liters per 1000kcal)',
#        'Freshwater withdrawals per 100g protein (liters per 100g protein)',
#        'Freshwater withdrawals per kilogram (liters per kilogram)',
#        'Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)',
#        'Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)',
#        'Land use per 1000kcal (m² per 1000kcal)',
#        'Land use per kilogram (m² per kilogram)',
#        'Land use per 100g protein (m² per 100g protein)',
#        'Scarcity-weighted water use per kilogram (liters per kilogram)',
# ...

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(12, 6))
plt.bar(df_food['Food product'], df_food['Total_emissions'])
plt.xticks(rotation=90)
plt.xlabel('Food Product')
plt.ylabel('Total Emissions')
plt.title('Total Emissions by Food Product')
plt.show()
plt.savefig('beef_max.jpeg')

# %% [markdown]
# *   This Beef(Beef Herd) product is having high emissions compared to remaining products.So this will impact environment severly.

# %%
# Group the data by 'Food product' and calculate the sum of 'Animal Feed'
grouped_data = df_food.groupby('Food product')['Animal Feed'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Animal Feed')
plt.title('Animal Feed by Food Product')
plt.xticks(rotation=90)
plt.show()
plt.savefig('animal_distribution.png')

# %% [markdown]
# *   This Pig Meat requires large amount of Animal Feed compared to remaining Food Products.

# %%
# Group the data by 'Food product' and calculate the sum of 'Farm'
grouped_data = df_food.groupby('Food product')['Farm'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Farm')
plt.title('Farm by Food Product')
plt.xticks(rotation=90)
plt.show()
plt.savefig('Farm_PRODUCT.png')

# %% [markdown]
# *   This Beef(Beef Herd)product also required more Farm land to do Cultivation and Harvesting compared to others.

# %%
# Group the data by 'Food product' and calculate the sum of 'Transport'
grouped_data = df_food.groupby('Food product')['Transport'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Transport')
plt.title('Transport by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   This Cane Sugar requires more transportation Facility for the Distribution of this product.

# %%
# Group the data by 'Food product' and calculate the sum of 'Packging'
grouped_data = df_food.groupby('Food product')['Packging'].sum()
# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Packging')
plt.title('Packging by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *  This Coffee(Food Product) requires a large amount of Packaging materials compared to other Food Products.

# %%
# Group the data by 'Food product' and calculate the sum of 'Transport'
grouped_data = df_food.groupby('Food product')['Retail'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Retail')
plt.title('Retail by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   This Food Products like Barley(Beef),Cheese,Milk,Soymilk,Tofu are having highest retail quantity compared to others which means these products with a large quantity are being sold or distributed grocery store operations.

# %%
# Group the data by 'Food product' and calculate the sum of 'Transport'
grouped_data = df_food.groupby('Food product')['Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)')
plt.title('Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal) by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   Coffee product has high number of nutrients(energy content of the product) that will effect the environment compared to other food products.

# %%
# Group the data by 'Food product' and calculate the sum of 'Transport'
grouped_data = df_food.groupby('Food product')['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Eutrophying emissions per kilogram (gPO₄eq per kilogram)')
plt.title('Eutrophying emissions per kilogram (gPO₄eq per kilogram) by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   Beef(dairy herd) has high number of eutrophying emissions based  on weight of the food product compared to other food products.

# %%
# Group the data by 'Food product' and calculate the sum of 'Transport'
grouped_data = df_food.groupby('Food product')['Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)'].sum()
plt.figure(figsize=(10, 6))
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Food product')
plt.ylabel('Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)')
plt.title('Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein) by Food Product')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   Beef(dairy herd) is also having high number of eutrophying emissions based on protein content compared to other food products.

# %%
# Calculate the total eutrophying emissions for each measure
total_1000kcal = df_food['Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)'].sum()
total_kilogram = df_food['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'].sum()
total_100g_protein = df_food['Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)'].sum()
labels = ['Eutrophying emissions per 1000kcal', 'Eutrophying emissions per kilogram', 'Eutrophying emissions per 100g protein']
values = [total_1000kcal, total_kilogram, total_100g_protein]
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Eutrophying Emissions')
plt.show()

# %% [markdown]
# *   Most of the Eutrophying emissions has greater impact on environment based on weight of the food products.

# %%
# Scatterplot to check the relation between each pair of numerical columns
pd.plotting.scatter_matrix(df_food, figsize=(20, 16), diagonal='kde')
plt.show()

# %%
#correlation matrix
plt.figure(figsize=(25,20))
sns.heatmap(df_food.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#removing duplicates from df_food data
df_food.drop_duplicates(keep='first', inplace=True)
df_food.shape
# Out:
# (43, 23)

# %%
unique_values = df_food['Food product'].unique()
print(unique_values)
# Out:
# ['Wheat & Rye (Bread)' 'Maize (Meal)' 'Barley (Beer)' 'Oatmeal' 'Rice'
#  'Potatoes' 'Cassava' 'Cane Sugar' 'Beet Sugar' 'Other Pulses' 'Peas'
#  'Nuts' 'Groundnuts' 'Soymilk' 'Tofu' 'Soybean Oil' 'Palm Oil'
#  'Sunflower Oil' 'Rapeseed Oil' 'Olive Oil' 'Tomatoes' 'Onions & Leeks'
#  'Root Vegetables' 'Brassicas' 'Other Vegetables' 'Citrus Fruit' 'Bananas'
#  'Apples' 'Berries & Grapes' 'Wine' 'Other Fruit' 'Coffee'
#  'Dark Chocolate' 'Beef (beef herd)' 'Beef (dairy herd)' 'Lamb & Mutton'
#  'Pig Meat' 'Poultry Meat' 'Milk' 'Cheese' 'Eggs' 'Fish (farmed)'
#  'Shrimps (farmed)']

# %%
xtr = df_food.drop('Total_emissions', axis=1)
xte = df_food['Total_emissions']

# %%
# Histogram to check the distribution of all the numerical columns
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
xtr.hist(ax = ax, bins = 15)
plt.show()
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
ytr = df_food[["Total_emissions"]]

# %%
ytr["Total_emissions"] = ytr["Total_emissions"].astype("category")

# %%
cat_cols = [col for col in xtr.columns if xtr.dtypes[col]=="object"]
cat_cols
# Out:
# ['Food product']

# %%
num_cols = [col for col in xtr.columns if xtr.dtypes[col] !="object"]
num_cols
# Out:
# ['Land use change',
#  'Animal Feed',
#  'Farm',
#  'Processing',
#  'Transport',
#  'Packging',
#  'Retail',
#  'Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)',
#  'Eutrophying emissions per kilogram (gPO₄eq per kilogram)',
#  'Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)',
#  'Freshwater withdrawals per 1000kcal (liters per 1000kcal)',
#  'Freshwater withdrawals per 100g protein (liters per 100g protein)',
#  'Freshwater withdrawals per kilogram (liters per kilogram)',
#  'Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)',
#  'Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)',
#  'Land use per 1000kcal (m² per 1000kcal)',
#  'Land use per kilogram (m² per kilogram)',
#  'Land use per 100g protein (m² per 100g protein)',
#  'Scarcity-weighted water use per kilogram (liters per kilogram)',
#  'Scarcity-weighted water use per 100g protein (liters per 100g protein)',
# ...

# %%
xtr_cat = xtr[cat_cols]
xtr_num = xtr[num_cols]
xte_cat = xtr[cat_cols]
xte_num = xtr[num_cols]

# %%
from sklearn.impute import SimpleImputer
cat_impu=SimpleImputer(strategy="most_frequent")
num_impu=SimpleImputer()
xtr_cat=pd.DataFrame(cat_impu.fit_transform(xtr_cat),columns=cat_cols)
xte_cat=pd.DataFrame(cat_impu.fit_transform(xte_cat),columns=cat_cols)
xtr_num=pd.DataFrame(num_impu.fit_transform(xtr_num),columns=num_cols)
xte_num=pd.DataFrame(num_impu.fit_transform(xte_num),columns=num_cols)

# %%
# Function to convert all object columns to categorical
xtr_cat[cat_cols]=xtr_cat[cat_cols].astype("category")
xte_cat[cat_cols]=xte_cat[cat_cols].astype("category")

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for col in cat_cols:
    xtr_cat[col]=encoder.fit_transform(xtr_cat[col])
    xte_cat[col]=encoder.fit_transform(xte_cat[col])

# %%
xtr_cat.head()
# Out:
#    Food product
# 0            41
# 1            18
# 2             2
# 3            21
# 4            33

# %%
df_food.shape
# Out:
# (43, 23)

# %%
xtr=pd.concat([xtr_num,xtr_cat],axis=1)

# %%
xte=pd.concat([xte_num,xte_cat],axis=1)

# %%
columnsxtr = xtr.columns
columnsxtr
# Out:
# Index(['Land use change', 'Animal Feed', 'Farm', 'Processing', 'Transport',
#        'Packging', 'Retail',
#        'Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)',
#        'Eutrophying emissions per kilogram (gPO₄eq per kilogram)',
#        'Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)',
#        'Freshwater withdrawals per 1000kcal (liters per 1000kcal)',
#        'Freshwater withdrawals per 100g protein (liters per 100g protein)',
#        'Freshwater withdrawals per kilogram (liters per kilogram)',
#        'Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)',
#        'Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)',
#        'Land use per 1000kcal (m² per 1000kcal)',
#        'Land use per kilogram (m² per kilogram)',
#        'Land use per 100g protein (m² per 100g protein)',
#        'Scarcity-weighted water use per kilogram (liters per kilogram)',
# ...

# %%
columnsxte = xte.columns
columnsxte
# Out:
# Index(['Land use change', 'Animal Feed', 'Farm', 'Processing', 'Transport',
#        'Packging', 'Retail',
#        'Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)',
#        'Eutrophying emissions per kilogram (gPO₄eq per kilogram)',
#        'Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)',
#        'Freshwater withdrawals per 1000kcal (liters per 1000kcal)',
#        'Freshwater withdrawals per 100g protein (liters per 100g protein)',
#        'Freshwater withdrawals per kilogram (liters per kilogram)',
#        'Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)',
#        'Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)',
#        'Land use per 1000kcal (m² per 1000kcal)',
#        'Land use per kilogram (m² per kilogram)',
#        'Land use per 100g protein (m² per 100g protein)',
#        'Scarcity-weighted water use per kilogram (liters per kilogram)',
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
scale.fit(xtr)
# Out:
# MinMaxScaler()

# %%
xtr = pd.DataFrame(scale.transform(xtr),columns=columnsxtr)

# %%
xtr.isnull().sum()
# Out:
# Land use change                                                            0
# Animal Feed                                                                0
# Farm                                                                       0
# Processing                                                                 0
# Transport                                                                  0
# Packging                                                                   0
# Retail                                                                     0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   0
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                   0
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      0
# Freshwater withdrawals per 1000kcal (liters per 1000kcal)                  0
# Freshwater withdrawals per 100g protein (liters per 100g protein)          0
# ...

# %%
xte.isnull().sum()
# Out:
# Land use change                                                            0
# Animal Feed                                                                0
# Farm                                                                       0
# Processing                                                                 0
# Transport                                                                  0
# Packging                                                                   0
# Retail                                                                     0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   0
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                   0
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      0
# Freshwater withdrawals per 1000kcal (liters per 1000kcal)                  0
# Freshwater withdrawals per 100g protein (liters per 100g protein)          0
# ...

# %%
xte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 22 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Land use change                                                          43 non-null     float64
#  1   Animal Feed                                                              43 non-null     float64
#  2   Farm                                                                     43 non-null     float64
#  3   Processing                                                               43 non-null     float64
#  4   Transport                                                                43 non-null     float64
#  5   Packging                                                                 43 non-null     float64
# ...

# %%
xte = pd.DataFrame(scale.transform(xte),columns=columnsxte)

# %%
xte.head()
# Out:
#    Land use change  Animal Feed      Farm  Processing  Transport  Packging  \
# 0         0.119565          0.0  0.017812    0.153846      0.125    0.0625
# 1         0.130435          0.0  0.010178    0.076923      0.125    0.0625
# 2         0.114130          0.0  0.002545    0.076923      0.000    0.3125
# 3         0.114130          0.0  0.033079    0.000000      0.125    0.0625
# 4         0.114130          0.0  0.089059    0.076923      0.125    0.0625
#
#      Retail  Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  \
# 0  0.333333                                           0.134621
# 1  0.000000                                           0.134621
# 2  1.000000                                           0.134621
# 3  0.000000                                           0.018169
# 4  0.333333                                           0.044780
#
#    Eutrophying emissions per kilogram (gPO₄eq per kilogram)  \
# 0                                           0.124661
# ...

# %%
#Plotting correlation
corrmat= xte.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(14,8))

#To plot heatmap
g=sns.heatmap(xte[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
for col in xtr.columns:
    print("for",col)
    plt.scatter(xtr[col],ytr)
    plt.show()
# Out:
# for Land use change
# for Animal Feed
# for Farm
# for Processing
# for Transport
# for Packging
# for Retail
# for Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)
# for Eutrophying emissions per kilogram (gPO₄eq per kilogram)
# for Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)
# for Freshwater withdrawals per 1000kcal (liters per 1000kcal)
# for Freshwater withdrawals per 100g protein (liters per 100g protein)
# for Freshwater withdrawals per kilogram (liters per kilogram)
# for Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)
# for Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)
# for Land use per 1000kcal (m² per 1000kcal)
# for Land use per kilogram (m² per kilogram)
# for Land use per 100g protein (m² per 100g protein)
# for Scarcity-weighted water use per kilogram (liters per kilogram)
# for Scarcity-weighted water use per 100g protein (liters per 100g protein)
# ...

# %%
from scipy.stats import pearsonr
for col in xtr.columns:
    print("correlation with Total_emissions", col)
    print(pearsonr(xtr[col],ytr["Total_emissions"]))
    print("-------------------------------")
# Out:
# correlation with Total_emissions Land use change
# PearsonRResult(statistic=0.801875439043766, pvalue=1.0302468137496279e-10)
# -------------------------------
# correlation with Total_emissions Animal Feed
# PearsonRResult(statistic=0.5746774120886947, pvalue=5.5726141429853765e-05)
# -------------------------------
# correlation with Total_emissions Farm
# PearsonRResult(statistic=0.969023676837887, pvalue=1.6001793545845054e-26)
# -------------------------------
# correlation with Total_emissions Processing
# PearsonRResult(statistic=0.7196725992644653, pvalue=5.3775830549344346e-08)
# -------------------------------
# correlation with Total_emissions Transport
# PearsonRResult(statistic=0.22450491621503618, pvalue=0.14780004380912393)
# -------------------------------
# correlation with Total_emissions Packging
# PearsonRResult(statistic=0.2050184421691079, pvalue=0.18722251644220578)
# -------------------------------
# correlation with Total_emissions Retail
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(xtr,ytr,test_size=0.2,random_state=142)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (34, 22)
# (9, 22)
# (34, 1)
# (9, 1)

# %%
from sklearn.metrics import precision_score,confusion_matrix,mean_absolute_error,mean_squared_error,classification_report
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
train_pred=reg.predict(X_train)
test_pred = reg.predict(X_test)
print('RMSE LinearRegression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE LinearRegression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE LinearRegression on train :  2.0369273485012186e-14
# RMSE LinearRegression on test :  1.331249536107179e-14

# %%
from sklearn.linear_model import Ridge, Lasso
#Ridge Regression Model
ridgeReg = Ridge(alpha=10)

ridgeReg.fit(X_train,y_train)

train_pred=ridgeReg.predict(X_train)
test_pred = ridgeReg.predict(X_test)
print('Ridge Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('Ridge Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# Ridge Regression on train :  5.564519473082619
# Ridge Regression on test :  2.858086123582182

# %%
#Lasso regression model
lasso = Lasso(alpha = 10)
lasso.fit(X_train,y_train)
train_pred=lasso.predict(X_train)
test_pred = lasso.predict(X_test)
print('lasso Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('lasso Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# lasso Regression on train :  11.483208743421098
# lasso Regression on test :  4.454230048058854

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(random_state=3,max_depth=9,min_samples_leaf=3)
model_RFR.fit(X_train, y_train)
train_pred=model_RFR.predict(X_train)
test_pred = model_RFR.predict(X_test)
print('RMSE RandomForestRegressor on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE RandomForestRegressor on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE RandomForestRegressor on train :  5.876713893995169
# RMSE RandomForestRegressor on test :  3.065073945198211

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree Regressor model
model_DTR = DecisionTreeRegressor(random_state=3, max_depth=9, min_samples_leaf=3)
model_DTR.fit(X_train, y_train)

# Make predictions on the training and test set
train_pred = model_DTR.predict(X_train)
test_pred = model_DTR.predict(X_test)

# Calculate RMSE for the training and test set
print('RMSE DecisionTreeRegressor on train:', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE DecisionTreeRegressor on test:', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE DecisionTreeRegressor on train: 5.341616576192907
# RMSE DecisionTreeRegressor on test: 5.596577023745501

# %% [markdown]
# *   Out of all Linear Regression is having least RMSE.
